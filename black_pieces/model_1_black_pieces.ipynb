# %% [markdown]
# # Black Pieces Test

# %%
ML_DATA_TRAIN_PATH = './../data/final_data_3/ml_final_data_train.csv'
ML_DATA_VAL_PATH = './../data/final_data_3/ml_final_data_val.csv'
ML_DATA_TEST_PATH = './../data/final_data_3/ml_final_data_test.csv'
MODEL_PATH = "./../stored_models/model_1_black_pieces.h5"
HISTORY_PATH = './../stored_models/history_model_1_black_pieces.json'
STEP_PATH = './../stored_models/history_step_model_1_black_pieces.json'
import sqlite3
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.client import device_lib
import os
import sys
from collections import Counter
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Input, BatchNormalization, Activation, Add, LeakyReLU, Concatenate, Multiply
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import layers
from tensorflow.keras.applications import InceptionResNetV2, VGG16, MobileNetV2
from tensorflow.keras.utils import to_categorical
from PIL import Image
import requests
import zipfile

import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output as cls
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
import pandas as pd
import PIL

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from pathlib import Path
import statistics
import ast
import json
import statistics

import glob
import cv2
from PIL import Image
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score
from sklearn.utils.class_weight import compute_class_weight

module_path = os.path.abspath(os.path.join('..', 'utils'))
if module_path not in sys.path:
    sys.path.append(module_path)

from utils2 import DataGenerator, plot_graph, bar_plot, two_bar_plot, StepwiseLogger

# %%
read_size = 524288
batch_size = 64
num_classes = 64
train_data_generator = DataGenerator(ML_DATA_TRAIN_PATH, read_size, batch_size, num_classes, 7761116, sparse_single_and_partial=True)
val_data_generator = DataGenerator(ML_DATA_VAL_PATH, read_size, batch_size, num_classes, 862347, sparse_single_and_partial=True)
test_data_generator = DataGenerator(ML_DATA_TEST_PATH, read_size, batch_size, num_classes, 958163, sparse_single_and_partial=True)

# %%
def residual_cnn_block(input, filters, kernel, padding):
    cnn = Conv2D(filters, kernel, padding=padding)(input)
    cnn = BatchNormalization()(cnn)
    cnn = LeakyReLU()(cnn)

    cnn = Conv2D(filters, kernel, padding=padding)(cnn)
    cnn = BatchNormalization()(cnn)

    cnn = Add()([input, cnn])
    cnn = LeakyReLU()(cnn)
    cnn = Dropout(0.1)(cnn)

    return cnn

# %%
def create_model(board_shape):
    board_input = Input(shape=board_shape)

    cnn = Conv2D(64, (3, 3), padding='same')(board_input)
    cnn = BatchNormalization()(cnn)
    cnn = LeakyReLU()(cnn)
    cnn = Dropout(0.1)(cnn)

    cnn = residual_cnn_block(cnn, 64, (3, 3), 'same')
    cnn = residual_cnn_block(cnn, 64, (3, 3), 'same')
    cnn = residual_cnn_block(cnn, 64, (3, 3), 'same')
    cnn = residual_cnn_block(cnn, 64, (3, 3), 'same')

    latent_space = Flatten()(cnn)
    
    mlp_initial_pos = Dense(512)(latent_space)
    mlp_initial_pos = BatchNormalization()(mlp_initial_pos)
    mlp_initial_pos = LeakyReLU()(mlp_initial_pos)
    mlp_initial_pos = Dense(256)(mlp_initial_pos)
    mlp_initial_pos = BatchNormalization()(mlp_initial_pos)
    mlp_initial_pos = LeakyReLU()(mlp_initial_pos)
    mlp_initial_pos = Dense(64)(mlp_initial_pos)
    mlp_initial_pos = BatchNormalization()(mlp_initial_pos)
    mlp_initial_pos = LeakyReLU()(mlp_initial_pos)
    mlp_initial_pos = Dense(64, activation='sigmoid')(mlp_initial_pos)

    initial_pos_preds = Dense(64, activation='softmax', name = 'initial_pos')(mlp_initial_pos)

    mlp_final_pos = Dense(512)(latent_space)
    mlp_final_pos = BatchNormalization()(mlp_final_pos)
    mlp_final_pos = LeakyReLU()(mlp_final_pos)
    mlp_final_pos = Dense(256)(mlp_final_pos)
    mlp_final_pos = BatchNormalization()(mlp_final_pos)
    mlp_final_pos = LeakyReLU()(mlp_final_pos)
    mlp_final_pos = Dense(64)(mlp_final_pos)
    mlp_final_pos = BatchNormalization()(mlp_final_pos)
    mlp_final_pos = LeakyReLU()(mlp_final_pos)
    mlp_final_pos = Dense(64, activation='sigmoid')(mlp_final_pos)

    final_pos_preds = Dense(64, activation='softmax', name = 'final_pos')(mlp_final_pos)

    move_input = Concatenate()([latent_space, mlp_initial_pos, mlp_final_pos])

    mlp_move = Dense(512)(move_input)
    mlp_move = BatchNormalization()(mlp_move)
    mlp_move = LeakyReLU()(mlp_move)

    mlp_move = Dense(4096, activation='softmax', name = 'full_move')(mlp_move)

    model = Model(inputs=board_input, outputs=[mlp_move, initial_pos_preds, final_pos_preds])
    return model

# %%
INPUT_SHAPE = (8, 8, 7)
model = create_model(INPUT_SHAPE)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 8, 8, 7)]    0           []
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 64)     4096        ['input_2[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 8, 8, 64)    256         ['conv2d_9[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 8, 8, 64)     0           ['batch_normalization_16[0][0]']
#
#  dropout_5 (Dropout)            (None, 8, 8, 64)     0           ['leaky_re_lu_16[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 64)     36928       ['dropout_5[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 8, 64)    256         ['conv2d_10[0][0]']
#  ormalization)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 8, 8, 64)     0           ['batch_normalization_17[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 64)     36928       ['leaky_re_lu_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 64)    256         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 64)     0           ['dropout_5[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 8, 8, 64)     0           ['add_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 8, 8, 64)     0           ['leaky_re_lu_18[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 64)     36928       ['dropout_6[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 64)    256         ['conv2d_12[0][0]']
#  ormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 8, 8, 64)     0           ['batch_normalization_19[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 64)     36928       ['leaky_re_lu_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 64)    256         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 8, 8, 64)     0           ['dropout_6[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 8, 8, 64)     0           ['add_5[0][0]']
#
#  dropout_7 (Dropout)            (None, 8, 8, 64)     0           ['leaky_re_lu_20[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 64)     36928       ['dropout_7[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 64)    256         ['conv2d_14[0][0]']
#  ormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 8, 8, 64)     0           ['batch_normalization_21[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 64)     36928       ['leaky_re_lu_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 64)    256         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 64)     0           ['dropout_7[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 8, 8, 64)     0           ['add_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 8, 8, 64)     0           ['leaky_re_lu_22[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 8, 8, 64)     36928       ['dropout_8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 64)    256         ['conv2d_16[0][0]']
#  ormalization)
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 8, 8, 64)     0           ['batch_normalization_23[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 8, 8, 64)     36928       ['leaky_re_lu_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 64)    256         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 8, 8, 64)     0           ['dropout_8[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)     (None, 8, 8, 64)     0           ['add_7[0][0]']
#
#  dropout_9 (Dropout)            (None, 8, 8, 64)     0           ['leaky_re_lu_24[0][0]']
#
#  flatten_1 (Flatten)            (None, 4096)         0           ['dropout_9[0][0]']
#
#  dense_9 (Dense)                (None, 512)          2097664     ['flatten_1[0][0]']
#
#  dense_13 (Dense)               (None, 512)          2097664     ['flatten_1[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 512)         2048        ['dense_9[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 512)         2048        ['dense_13[0][0]']
#  ormalization)
#
#  leaky_re_lu_25 (LeakyReLU)     (None, 512)          0           ['batch_normalization_25[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)     (None, 512)          0           ['batch_normalization_28[0][0]']
#
#  dense_10 (Dense)               (None, 256)          131328      ['leaky_re_lu_25[0][0]']
#
#  dense_14 (Dense)               (None, 256)          131328      ['leaky_re_lu_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 256)         1024        ['dense_10[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 256)         1024        ['dense_14[0][0]']
#  ormalization)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, 256)          0           ['batch_normalization_26[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)     (None, 256)          0           ['batch_normalization_29[0][0]']
#
#  dense_11 (Dense)               (None, 64)           16448       ['leaky_re_lu_26[0][0]']
#
#  dense_15 (Dense)               (None, 64)           16448       ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64)          256         ['dense_11[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 64)          256         ['dense_15[0][0]']
#  ormalization)
#
#  leaky_re_lu_27 (LeakyReLU)     (None, 64)           0           ['batch_normalization_27[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)     (None, 64)           0           ['batch_normalization_30[0][0]']
#
#  dense_12 (Dense)               (None, 64)           4160        ['leaky_re_lu_27[0][0]']
#
#  dense_16 (Dense)               (None, 64)           4160        ['leaky_re_lu_30[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4224)         0           ['flatten_1[0][0]',
#                                                                   'dense_12[0][0]',
#                                                                   'dense_16[0][0]']
#
#  dense_17 (Dense)               (None, 512)          2163200     ['concatenate_1[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 512)         2048        ['dense_17[0][0]']
#  ormalization)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, 512)          0           ['batch_normalization_31[0][0]']
#
#  full_move (Dense)              (None, 4096)         2101248     ['leaky_re_lu_31[0][0]']
#
#  initial_pos (Dense)            (None, 64)           4160        ['dense_12[0][0]']
#
#  final_pos (Dense)              (None, 64)           4160        ['dense_16[0][0]']
#
# ==================================================================================================
# Total params: 9,082,496
# Trainable params: 9,076,992
# Non-trainable params: 5,504
# __________________________________________________________________________________________________

# %%
losses = {
    'full_move': 'sparse_categorical_crossentropy',
    'initial_pos': 'sparse_categorical_crossentropy',
    'final_pos': 'sparse_categorical_crossentropy'
}

# %%
model.compile(optimizer='Adam', loss=losses, metrics='accuracy')
steps_per_epoch_val = len(val_data_generator)
stepwise_logger = StepwiseLogger(val_data_generator, steps_per_epoch_val, 40000, divide=50)

# %%
history = model.fit(train_data_generator, epochs=20, validation_data=val_data_generator, shuffle=False, callbacks=[stepwise_logger, ModelCheckpoint(MODEL_PATH, save_best_only=True), EarlyStopping(patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/20
#      4/121268 [..............................] - ETA: 35:03 - loss: 16.6633 - full_move_loss: 8.2936 - initial_pos_loss: 4.2040 - final_pos_loss: 4.1657 - full_move_accuracy: 0.0195 - initial_pos_accuracy: 0.0078 - final_pos_accuracy: 0.0078            WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0156s vs `on_train_batch_end` time: 0.0164s). Check your callbacks.
# 121268/121268 [==============================] - 2962s 24ms/step - loss: 5.9937 - full_move_loss: 2.3446 - initial_pos_loss: 1.4913 - final_pos_loss: 2.1577 - full_move_accuracy: 0.3550 - initial_pos_accuracy: 0.4803 - final_pos_accuracy: 0.3811 - val_loss: 5.7360 - val_full_move_loss: 2.2381 - val_initial_pos_loss: 1.4341 - val_final_pos_loss: 2.0638 - val_full_move_accuracy: 0.3739 - val_initial_pos_accuracy: 0.4939 - val_final_pos_accuracy: 0.4007
# Epoch 2/20
# 121268/121268 [==============================] - 2948s 24ms/step - loss: 5.5800 - full_move_loss: 2.1799 - initial_pos_loss: 1.4065 - final_pos_loss: 1.9935 - full_move_accuracy: 0.3839 - initial_pos_accuracy: 0.5042 - final_pos_accuracy: 0.4104 - val_loss: 5.3569 - val_full_move_loss: 2.0885 - val_initial_pos_loss: 1.3569 - val_final_pos_loss: 1.9115 - val_full_move_accuracy: 0.3988 - val_initial_pos_accuracy: 0.5161 - val_final_pos_accuracy: 0.4238
# Epoch 3/20
# 121268/121268 [==============================] - 2963s 24ms/step - loss: 5.4069 - full_move_loss: 2.1128 - initial_pos_loss: 1.3648 - final_pos_loss: 1.9293 - full_move_accuracy: 0.3943 - initial_pos_accuracy: 0.5156 - final_pos_accuracy: 0.4172 - val_loss: 5.2089 - val_full_move_loss: 2.0342 - val_initial_pos_loss: 1.3241 - val_final_pos_loss: 1.8506 - val_full_move_accuracy: 0.4108 - val_initial_pos_accuracy: 0.5263 - val_final_pos_accuracy: 0.4367
# Epoch 4/20
# 121268/121268 [==============================] - 2963s 24ms/step - loss: 5.2838 - full_move_loss: 2.0659 - initial_pos_loss: 1.3412 - final_pos_loss: 1.8767 - full_move_accuracy: 0.4039 - initial_pos_accuracy: 0.5225 - final_pos_accuracy: 0.4284 - val_loss: 5.1005 - val_full_move_loss: 2.0011 - val_initial_pos_loss: 1.2963 - val_final_pos_loss: 1.8031 - val_full_move_accuracy: 0.4171 - val_initial_pos_accuracy: 0.5341 - val_final_pos_accuracy: 0.4432
# Epoch 5/20
# 121268/121268 [==============================] - 2952s 24ms/step - loss: 5.2198 - full_move_loss: 2.0372 - initial_pos_loss: 1.3324 - final_pos_loss: 1.8502 - full_move_accuracy: 0.4084 - initial_pos_accuracy: 0.5240 - final_pos_accuracy: 0.4344 - val_loss: 5.0238 - val_full_move_loss: 1.9667 - val_initial_pos_loss: 1.2847 - val_final_pos_loss: 1.7725 - val_full_move_accuracy: 0.4239 - val_initial_pos_accuracy: 0.5391 - val_final_pos_accuracy: 0.4501
# Epoch 6/20
# 121268/121268 [==============================] - 2957s 24ms/step - loss: 5.1541 - full_move_loss: 2.0146 - initial_pos_loss: 1.3134 - final_pos_loss: 1.8261 - full_move_accuracy: 0.4140 - initial_pos_accuracy: 0.5312 - final_pos_accuracy: 0.4378 - val_loss: 4.9785 - val_full_move_loss: 1.9491 - val_initial_pos_loss: 1.2733 - val_final_pos_loss: 1.7561 - val_full_move_accuracy: 0.4246 - val_initial_pos_accuracy: 0.5411 - val_final_pos_accuracy: 0.4515
# Epoch 7/20
# 121268/121268 [==============================] - 2952s 24ms/step - loss: 5.1061 - full_move_loss: 2.0010 - initial_pos_loss: 1.2958 - final_pos_loss: 1.8092 - full_move_accuracy: 0.4179 - initial_pos_accuracy: 0.5348 - final_pos_accuracy: 0.4427 - val_loss: 4.9485 - val_full_move_loss: 1.9401 - val_initial_pos_loss: 1.2693 - val_final_pos_loss: 1.7392 - val_full_move_accuracy: 0.4277 - val_initial_pos_accuracy: 0.5432 - val_final_pos_accuracy: 0.4557
# Epoch 8/20
# 121268/121268 [==============================] - 2957s 24ms/step - loss: 5.0741 - full_move_loss: 1.9858 - initial_pos_loss: 1.2944 - final_pos_loss: 1.7939 - full_move_accuracy: 0.4199 - initial_pos_accuracy: 0.5353 - final_pos_accuracy: 0.4449 - val_loss: 4.9212 - val_full_move_loss: 1.9332 - val_initial_pos_loss: 1.2594 - val_final_pos_loss: 1.7287 - val_full_move_accuracy: 0.4303 - val_initial_pos_accuracy: 0.5469 - val_final_pos_accuracy: 0.4568
# Epoch 9/20
# 121268/121268 [==============================] - 2951s 24ms/step - loss: 5.0260 - full_move_loss: 1.9631 - initial_pos_loss: 1.2865 - final_pos_loss: 1.7764 - full_move_accuracy: 0.4253 - initial_pos_accuracy: 0.5377 - final_pos_accuracy: 0.4492 - val_loss: 4.8823 - val_full_move_loss: 1.9195 - val_initial_pos_loss: 1.2513 - val_final_pos_loss: 1.7116 - val_full_move_accuracy: 0.4321 - val_initial_pos_accuracy: 0.5479 - val_final_pos_accuracy: 0.4610
# Epoch 10/20
# 121268/121268 [==============================] - 2972s 24ms/step - loss: 5.0017 - full_move_loss: 1.9592 - initial_pos_loss: 1.2755 - final_pos_loss: 1.7669 - full_move_accuracy: 0.4238 - initial_pos_accuracy: 0.5435 - final_pos_accuracy: 0.4480 - val_loss: 4.8666 - val_full_move_loss: 1.9095 - val_initial_pos_loss: 1.2504 - val_final_pos_loss: 1.7068 - val_full_move_accuracy: 0.4340 - val_initial_pos_accuracy: 0.5492 - val_final_pos_accuracy: 0.4617
# Epoch 11/20
# 121268/121268 [==============================] - 2974s 24ms/step - loss: 4.9746 - full_move_loss: 1.9471 - initial_pos_loss: 1.2714 - final_pos_loss: 1.7562 - full_move_accuracy: 0.4292 - initial_pos_accuracy: 0.5444 - final_pos_accuracy: 0.4529 - val_loss: 4.8320 - val_full_move_loss: 1.9005 - val_initial_pos_loss: 1.2420 - val_final_pos_loss: 1.6894 - val_full_move_accuracy: 0.4374 - val_initial_pos_accuracy: 0.5510 - val_final_pos_accuracy: 0.4655
# Epoch 12/20
# 121268/121268 [==============================] - 2960s 24ms/step - loss: 4.9510 - full_move_loss: 1.9355 - initial_pos_loss: 1.2664 - final_pos_loss: 1.7491 - full_move_accuracy: 0.4320 - initial_pos_accuracy: 0.5441 - final_pos_accuracy: 0.4515 - val_loss: 4.8288 - val_full_move_loss: 1.9031 - val_initial_pos_loss: 1.2389 - val_final_pos_loss: 1.6868 - val_full_move_accuracy: 0.4370 - val_initial_pos_accuracy: 0.5537 - val_final_pos_accuracy: 0.4664
# Epoch 13/20
# 121268/121268 [==============================] - 3038s 25ms/step - loss: 4.9290 - full_move_loss: 1.9309 - initial_pos_loss: 1.2632 - final_pos_loss: 1.7349 - full_move_accuracy: 0.4309 - initial_pos_accuracy: 0.5464 - final_pos_accuracy: 0.4568 - val_loss: 4.8134 - val_full_move_loss: 1.9004 - val_initial_pos_loss: 1.2358 - val_final_pos_loss: 1.6771 - val_full_move_accuracy: 0.4354 - val_initial_pos_accuracy: 0.5532 - val_final_pos_accuracy: 0.4679
# Epoch 14/20
# 121268/121268 [==============================] - 3053s 25ms/step - loss: 4.9208 - full_move_loss: 1.9259 - initial_pos_loss: 1.2646 - final_pos_loss: 1.7303 - full_move_accuracy: 0.4326 - initial_pos_accuracy: 0.5457 - final_pos_accuracy: 0.4572 - val_loss: 4.7959 - val_full_move_loss: 1.8882 - val_initial_pos_loss: 1.2302 - val_final_pos_loss: 1.6774 - val_full_move_accuracy: 0.4384 - val_initial_pos_accuracy: 0.5550 - val_final_pos_accuracy: 0.4669
# Epoch 15/20
# 121268/121268 [==============================] - 3149s 26ms/step - loss: 4.9126 - full_move_loss: 1.9246 - initial_pos_loss: 1.2592 - final_pos_loss: 1.7288 - full_move_accuracy: 0.4316 - initial_pos_accuracy: 0.5468 - final_pos_accuracy: 0.4560 - val_loss: 4.7884 - val_full_move_loss: 1.8867 - val_initial_pos_loss: 1.2324 - val_final_pos_loss: 1.6693 - val_full_move_accuracy: 0.4403 - val_initial_pos_accuracy: 0.5551 - val_final_pos_accuracy: 0.4694
# Epoch 16/20
# 121268/121268 [==============================] - 3176s 26ms/step - loss: 4.8697 - full_move_loss: 1.9101 - initial_pos_loss: 1.2458 - final_pos_loss: 1.7139 - full_move_accuracy: 0.4341 - initial_pos_accuracy: 0.5522 - final_pos_accuracy: 0.4601 - val_loss: 4.7755 - val_full_move_loss: 1.8864 - val_initial_pos_loss: 1.2282 - val_final_pos_loss: 1.6608 - val_full_move_accuracy: 0.4400 - val_initial_pos_accuracy: 0.5563 - val_final_pos_accuracy: 0.4708
# Epoch 17/20
# 121268/121268 [==============================] - 3167s 26ms/step - loss: 4.8595 - full_move_loss: 1.9033 - initial_pos_loss: 1.2452 - final_pos_loss: 1.7110 - full_move_accuracy: 0.4380 - initial_pos_accuracy: 0.5524 - final_pos_accuracy: 0.4601 - val_loss: 4.7608 - val_full_move_loss: 1.8810 - val_initial_pos_loss: 1.2229 - val_final_pos_loss: 1.6570 - val_full_move_accuracy: 0.4412 - val_initial_pos_accuracy: 0.5580 - val_final_pos_accuracy: 0.4731
# Epoch 18/20
# 121268/121268 [==============================] - 3131s 26ms/step - loss: 4.8497 - full_move_loss: 1.9000 - initial_pos_loss: 1.2440 - final_pos_loss: 1.7057 - full_move_accuracy: 0.4384 - initial_pos_accuracy: 0.5518 - final_pos_accuracy: 0.4629 - val_loss: 4.7461 - val_full_move_loss: 1.8710 - val_initial_pos_loss: 1.2244 - val_final_pos_loss: 1.6507 - val_full_move_accuracy: 0.4430 - val_initial_pos_accuracy: 0.5573 - val_final_pos_accuracy: 0.4727
# Epoch 19/20
# 121268/121268 [==============================] - 3128s 26ms/step - loss: 4.8485 - full_move_loss: 1.8964 - initial_pos_loss: 1.2455 - final_pos_loss: 1.7067 - full_move_accuracy: 0.4387 - initial_pos_accuracy: 0.5503 - final_pos_accuracy: 0.4615 - val_loss: 4.7644 - val_full_move_loss: 1.8792 - val_initial_pos_loss: 1.2263 - val_final_pos_loss: 1.6588 - val_full_move_accuracy: 0.4423 - val_initial_pos_accuracy: 0.5565 - val_final_pos_accuracy: 0.4707
# Epoch 20/20
# 121268/121268 [==============================] - 3062s 25ms/step - loss: 4.8440 - full_move_loss: 1.8991 - initial_pos_loss: 1.2413 - final_pos_loss: 1.7036 - full_move_accuracy: 0.4390 - initial_pos_accuracy: 0.5514 - final_pos_accuracy: 0.4632 - val_loss: 4.7461 - val_full_move_loss: 1.8780 - val_initial_pos_loss: 1.2187 - val_final_pos_loss: 1.6493 - val_full_move_accuracy: 0.4433 - val_initial_pos_accuracy: 0.5596 - val_final_pos_accuracy: 0.4739

# %%
plot_graph(history=stepwise_logger)

# %%
plot_graph(history=history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Usuario\anaconda3\envs\py310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'accuracy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plot_graph(history=history)
#
# File c:\Users\Usuario\Desktop\Pablo\Master\TFM\Chess\project\utils\utils2.py:189, in plot_graph(history)
#     187 plt.subplot(1,2,2)
#     188 plt.title("Accuracy Curve")
# --> 189 plt.plot(df['accuracy'], label="Accuracy")
#     190 plt.plot(df['val_accuracy'], label="Val Accuracy")
#     191 plt.xlabel("Epochs")
#
# File c:\Users\Usuario\anaconda3\envs\py310\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Usuario\anaconda3\envs\py310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'accuracy'

# %%
model.evaluate(test_data_generator)
# Out:
# 14972/14972 [==============================] - 166s 10ms/step - loss: 4.7402 - full_move_loss: 1.8767 - initial_pos_loss: 1.2169 - final_pos_loss: 1.6467 - full_move_accuracy: 0.4442 - initial_pos_accuracy: 0.5610 - final_pos_accuracy: 0.4749
# [4.740217685699463,
#  1.8766684532165527,
#  1.2168710231781006,
#  1.6466777324676514,
#  0.4441540837287903,
#  0.5609995126724243,
#  0.474949449300766]

# %%
model.save(MODEL_PATH)

# %%
with open(HISTORY_PATH, 'w') as file:
    json.dump(history.history, file)

with open(STEP_PATH, 'w') as file:
    json.dump(stepwise_logger.history, file)
